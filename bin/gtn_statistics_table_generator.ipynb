# %% [markdown]
# # Statistics for microbial-related statistics

# %% [markdown]
# This notebook explores the microbial-related tutorials stored on the [Galaxy Training Network](https://training.galaxyproject.org/)

# %%
#import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import requests
from owlready2 import get_ontology, Thing
#from bs4 import BeautifulSoup
#from googleapiclient.discovery import build
#import json
#from dateutil import relativedelta
#from urllib.parse import quote
#import os
#import zipfile
#from io import BytesIO
#from datetime import datetime
# Out:
# Warning: SQLite3 version 3.40.0 and 3.41.2 have huge performance regressions; please install version 3.41.1 or 3.42!

# %% [markdown]
# # Retrieve microbial-related GTN tutorials

# %% [markdown]
# Microbial-related tutorials are tagged with `microgalaxy`

# %%
def get_request_json(url):
    r = requests.get(url)
    r.raise_for_status()
    return r.json()

# Get all tutorials tagged with microgalaxy and store them into a list of dictionary
microgalaxy_tutos = []
topics = get_request_json('https://training.galaxyproject.org/training-material/api/topics.json')
edam_ontology = get_ontology('https://edamontology.org/EDAM_1.25.owl').load()
for topic in topics:
    topic_information = get_request_json(f"https://training.galaxyproject.org/training-material/api/topics/{topic}.json")
    for tuto in topic_information["materials"]:
        if tuto is None:
            continue
        if "tags" in tuto and tuto["tags"] is not None and "microgalaxy" in tuto["tags"]:
            tuto["url"] = f'https://training.galaxyproject.org/{tuto["url"]}'
            tuto["mod_date"] = datetime.fromisoformat(tuto["mod_date"]).strftime("%Y-%m-%d")
            tuto["pub_date"] = datetime.fromisoformat(tuto["pub_date"]).strftime("%Y-%m-%d")
            # Split supported_servers into 2 lists there 
            if "supported_servers" in tuto:
                if "exact" in tuto["supported_servers"]:
                    tuto["exact_supported_servers"] = [server["name"] for server in tuto["supported_servers"]["exact"]]
                if "inexact" in tuto["supported_servers"]:
                    tuto["inexact_supported_servers"] = [server["name"] for server in tuto["supported_servers"]["inexact"]]
            # Get tool ids without toolshed URL
            if "tools" in tuto:
                tuto["short_tools"] = []
                for tool in tuto["tools"]:
                    if "toolshed" in tool:
                        tuto["short_tools"].append(tool.split("/")[-3])
                    else:
                        tuto["short_tools"].append(tool)
            # Get EDAM labels instead of EDAM ids
            if "edam_ontology" in tuto:
                tuto["EDAM Topic"] = []
                tuto["EDAM Operation"] = []
                for term in tuto["edam_ontology"]:
                    if "topic" in term:
                        tuto["EDAM Topic"] += edam_ontology[term].label
                    elif "operation" in term:
                        tuto["EDAM Operation"] += edam_ontology[term].label
            microgalaxy_tutos.append(tuto)
            # ADD FEEDBACK EXTRACTION HERE
            # ADD YOUTUBE STATS HERE

# %%
# Transform the list of dictionary with tutorials into a dataframe exportable to TSV
# TO MOVE AT THE END 
microgalaxy_tuto_df = (
    pd.DataFrame.from_dict(microgalaxy_tutos)
    .assign(
        Workflows=lambda df: df.workflows.notna()
    )
    .rename(columns = {
        "title": "Title",
        "hands_on": "Tutorial",
        "url": "Link",
        "slides": "Slides",
        "mod_date": "Last modification",
        "pub_date": "Creation",
        "version": "Version",
        "short_tools": "Tools",
        "exact_supported_servers": "Servers with precise tool versions",
        "inexact_supported_servers": "Servers with tool but different versions",
        "topic_name_human": "Topic",
        "video": "Video",
    })
    .reindex(columns = [
        "Topic",
        "Title",
        "Link",
        "EDAM Topic",
        "EDAM Operation",
        "Creation",
        "Last modification",
        "Version",
        "Tutorial",
        "Slides",
        "Video",
        "Workflows",
        "Tools",
        "Servers with precise tool versions",
        "Servers with tool but different versions"
    ])
    .fillna("")
)
for col in ["Servers with precise tool versions", "Servers with tool but different versions", "Tools", "EDAM Topic", "EDAM Operation"]:
    microgalaxy_tuto_df[col] = microgalaxy_tuto_df[col].apply(lambda x: ", ".join([str(i) for i in x]))
microgalaxy_tuto_df.to_csv("../results/tutorials.tsv", sep="\t")
microgalaxy_tuto_df
# Out:
#                 Topic                                              Title  \
# 0            Assembly  Genome Assembly of MRSA from Oxford Nanopore M...
# 1            Assembly           Making sense of a newly assembled genome
# 2            Assembly                                 Unicycler Assembly
# 3            Assembly            Assembly of metagenomic sequencing data
# 4            Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 5             Ecology  Checking expected species and contamination in...
# 6           Evolution  Tree thinking for tuberculosis evolution and e...
# 7           Evolution  Identifying tuberculosis transmission links: f...
# 8   Genome Annotation                      Genome annotation with Prokka
# 9   Genome Annotation  Refining Genome Annotations with Apollo (proka...
# 10  Genome Annotation                        Bacterial Genome Annotation
# 11  Genome Annotation   Comparative gene analysis in unannotated genomes
# 12  Genome Annotation                      Genome annotation with Prokka
# 13           Assembly  Genome Assembly of MRSA from Oxford Nanopore M...
# 14           Assembly           Making sense of a newly assembled genome
# 15   Variant Analysis                          Microbial Variant Calling
# 16  Genome Annotation  Refining Genome Annotations with Apollo (proka...
# 17  Genome Annotation                        Bacterial Genome Annotation
# 18         Microbiome  Analyses of metagenomics data - The global pic...
# 19         Microbiome  Identification of the micro-organisms in a bee...
# 20         Microbiome  Metatranscriptomics analysis using microbiome ...
# 21         Microbiome  Taxonomic Profiling and Visualization of Metag...
# 22         Microbiome      16S Microbial Analysis with mothur (extended)
# 23         Microbiome            Assembly of metagenomic sequencing data
# 24         Microbiome         16S Microbial Analysis with mothur (short)
# 25         Microbiome                    Antibiotic resistance detection
# 26         Microbiome  Pathogen detection from (direct Nanopore) sequ...
# 27         Microbiome          16S Microbial analysis with Nanopore data
# 28         Microbiome  Metatranscriptomics analysis using microbiome ...
# 29         Microbiome             Binning of metagenomic sequencing data
# 30         Microbiome             QIIME 2 Cancer Microbiome Intervention
# 31   Variant Analysis                   M. tuberculosis Variant Analysis
# 32          Evolution  Tree thinking for tuberculosis evolution and e...
# 33          Evolution  Identifying tuberculosis transmission links: f...
# 34         Proteomics                      metaQuantome 1: Data creation
# 35         Proteomics                           metaQuantome 3: Taxonomy
# 36         Proteomics                            Metaproteomics tutorial
# 37         Proteomics                           metaQuantome 2: Function
# 38   Variant Analysis            Calling variants in non-diploid systems
# 39   Variant Analysis                          Microbial Variant Calling
# 40   Variant Analysis                   M. tuberculosis Variant Analysis
#
#                                                  Link  EDAM Topic  \
# 0   https://training.galaxyproject.org//topics/ass...
# 1   https://training.galaxyproject.org//topics/ass...
# 2   https://training.galaxyproject.org//topics/ass...
# 3   https://training.galaxyproject.org//topics/ass...
# 4   https://training.galaxyproject.org//topics/ass...
# 5   https://training.galaxyproject.org//topics/eco...
# 6   https://training.galaxyproject.org//topics/evo...
# 7   https://training.galaxyproject.org//topics/evo...
# 8   https://training.galaxyproject.org//topics/gen...
# 9   https://training.galaxyproject.org//topics/gen...
# 10  https://training.galaxyproject.org//topics/gen...
# 11  https://training.galaxyproject.org//topics/gen...
# 12  https://training.galaxyproject.org//topics/gen...
# 13  https://training.galaxyproject.org//topics/ass...
# 14  https://training.galaxyproject.org//topics/ass...
# 15  https://training.galaxyproject.org//topics/var...
# 16  https://training.galaxyproject.org//topics/gen...
# 17  https://training.galaxyproject.org//topics/gen...
# 18  https://training.galaxyproject.org//topics/mic...
# 19  https://training.galaxyproject.org//topics/mic...
# 20  https://training.galaxyproject.org//topics/mic...
# 21  https://training.galaxyproject.org//topics/mic...
# 22  https://training.galaxyproject.org//topics/mic...
# 23  https://training.galaxyproject.org//topics/mic...
# 24  https://training.galaxyproject.org//topics/mic...
# 25  https://training.galaxyproject.org//topics/mic...
# 26  https://training.galaxyproject.org//topics/mic...
# 27  https://training.galaxyproject.org//topics/mic...
# 28  https://training.galaxyproject.org//topics/mic...
# 29  https://training.galaxyproject.org//topics/mic...
# 30  https://training.galaxyproject.org//topics/mic...
# 31  https://training.galaxyproject.org//topics/var...
# 32  https://training.galaxyproject.org//topics/evo...
# 33  https://training.galaxyproject.org//topics/evo...
# 34  https://training.galaxyproject.org//topics/pro...
# 35  https://training.galaxyproject.org//topics/pro...
# 36  https://training.galaxyproject.org//topics/pro...  Proteomics
# 37  https://training.galaxyproject.org//topics/pro...
# 38  https://training.galaxyproject.org//topics/var...
# 39  https://training.galaxyproject.org//topics/var...
# 40  https://training.galaxyproject.org//topics/var...
#
#    EDAM Operation    Creation Last modification  Version  Tutorial  Slides  \
# 0                  2021-03-24        2024-02-29       33      True   False
# 1                  2018-06-14        2024-02-29       85      True   False
# 2                  2017-10-11        2023-11-28       60      True    True
# 3                  2024-03-06        2024-03-06        0      True   False
# 4                  2021-03-24        2024-02-16       27      True   False
# 5                  2024-03-04        2024-01-29        1      True   False
# 6                  2022-03-16        2023-11-28       17      True   False
# 7                  2022-03-16        2023-11-28       14      True   False
# 8                  2018-03-06        2024-02-29       40      True    True
# 9                  2021-06-04        2024-02-29       38      True    True
# 10                 2024-02-01        2024-02-29        7      True   False
# 11                 2022-09-08        2023-11-28       28      True   False
# 12                 2018-03-06        2024-02-29       40      True    True
# 13                 2021-03-24        2024-02-29       33      True   False
# 14                 2018-06-14        2024-02-29       85      True   False
# 15                 2018-02-26        2024-02-29       35      True   False
# 16                 2021-06-04        2024-02-29       38      True    True
# 17                 2024-02-01        2024-02-29        7      True   False
# 18                 2017-06-22        2024-01-11        1      True   False
# 19                 2022-09-29        2024-01-11        1      True   False
# 20                 2020-02-13        2024-01-11        1      True   False
# 21                 2023-05-03        2024-01-11        1      True   False
# 22                 2017-02-12        2024-01-11        1      True   False
# 23                 2022-12-05        2024-01-11        1      True   False
# 24                 2019-05-13        2024-01-11        1      True   False
# 25                 2019-06-25        2024-01-11        1      True   False
# 26                 2023-01-26        2024-01-11        1      True   False
# 27                 2020-11-24        2024-01-11        1      True   False
# 28                 2019-11-21        2024-01-11        1      True    True
# 29                 2023-12-05        2024-01-11        1      True   False
# 30                 2024-02-12        2024-02-12        2  external   False
# 31                 2020-07-25        2023-11-28       61      True   False
# 32                 2022-03-16        2023-11-28       17      True   False
# 33                 2022-03-16        2023-11-28       14      True   False
# 34                 2020-10-16        2024-01-24       89      True   False
# 35                 2020-10-29        2023-11-28       35      True   False
# 36                 2017-06-28        2023-11-28       54      True   False
# 37                 2020-10-29        2023-11-28       37      True   False
# 38                 2017-02-16        2023-11-28       38      True   False
# 39                 2018-02-26        2024-02-29       35      True   False
# 40                 2020-07-25        2023-11-28       61      True   False
#
#     Video  Workflows                                              Tools  \
# 0   False       True  CONVERTER_bz2_to_uncompressed, flye, fastqc, b...
# 1   False       True  Cut1, Filter1, Grep1, cat1, join1, random_line...
# 2   False       True          prokka, fastqc, multiqc, quast, unicycler
# 3   False       True  random_lines1, text_processing, unique, bamtoo...
# 4   False       True  fastqc, bandage, bandage, fastp, quast, shovil...
# 5   False       True   bracken, bracken, kraken2, recentrifuge, upload1
# 6   False       True    interactive_tool_rstudio, raxml, raxml, upload1
# 7   False       True  Grep1, __MERGE_COLLECTION__, text_processing, ...
# 8    True       True                   prokka, prokka, jbrowse, jbrowse
# 9    True       True  apollo_create_account, apollo_create_or_update...
# 10  False       True  Grouping1, text_processing, text_processing, b...
# 11  False       True  Cut1, Filter1, cat1, join1, diamond, diamond, ...
# 12   True       True                   prokka, prokka, jbrowse, jbrowse
# 13  False       True  CONVERTER_bz2_to_uncompressed, flye, fastqc, b...
# 14  False       True  Cut1, Filter1, Grep1, cat1, join1, random_line...
# 15  False       True                                    jbrowse, snippy
# 16   True       True  apollo_create_account, apollo_create_or_update...
# 17  False       True  Grouping1, text_processing, text_processing, b...
# 18  False       True  taxonomy_krona_chart, humann2, humann2_regroup...
# 19  False       True  Filter1, taxonomy_krona_chart, fastqc, fastp, ...
# 20  False       True  Cut1, Grep1, combine_metaphlan2_humann2, text_...
# 21  False       True  __UNZIP_COLLECTION__, interactive_tool_pavian,...
# 22  False       True  taxonomy_krona_chart, xy_plot, mothur_align_se...
# 23  False       True  random_lines1, text_processing, unique, bamtoo...
# 24  False       True  xy_plot, mothur_chimera_vsearch, mothur_classi...
# 25  False       True  racon, racon, bandage, bandage, gfa_to_fa, gfa...
# 26  False       True  CONVERTER_gz_to_uncompressed, Cut1, Paste1, Re...
# 27  False       True  Remove beginning1, text_processing, taxonomy_k...
# 28  False       True  Cut1, Grep1, combine_metaphlan2_humann2, text_...
# 29  False      False                         checkm_lineage_wf, megahit
# 30  False      False
# 31  False       True  text_processing, emboss_5, fastqc, samtools_st...
# 32  False       True    interactive_tool_rstudio, raxml, raxml, upload1
# 33  False       True  Grep1, __MERGE_COLLECTION__, text_processing, ...
# 34  False       True  Cut1, Filter1, Grep1, Remove beginning1, text_...
# 35  False       True  metaquantome_db, metaquantome_expand, metaquan...
# 36  False       True  peptideshaker, peptideshaker, unipept, query_t...
# 37  False       True  metaquantome_db, metaquantome_db, metaquantome...
# 38  False       True  Cut1, bamtools_filter, bwa, fastqc, freebayes,...
# 39  False       True                                    jbrowse, snippy
# 40  False       True  text_processing, emboss_5, fastqc, samtools_st...
#
#                    Servers with precise tool versions  \
# 0                                        UseGalaxy.eu
# 1
# 2   UseGalaxy.be, UseGalaxy.eu, UseGalaxy.org (Mai...
# 3
# 4    UseGalaxy.eu, UseGalaxy.fr, UseGalaxy.org (Main)
# 5                                        UseGalaxy.eu
# 6                                        UseGalaxy.eu
# 7                                        UseGalaxy.eu
# 8    UseGalaxy.be, UseGalaxy.eu, UseGalaxy.org (Main)
# 9
# 10                         UseGalaxy.eu, UseGalaxy.fr
# 11                 UseGalaxy.eu, UseGalaxy.org (Main)
# 12   UseGalaxy.be, UseGalaxy.eu, UseGalaxy.org (Main)
# 13                                       UseGalaxy.eu
# 14
# 15   UseGalaxy.be, UseGalaxy.eu, UseGalaxy.org (Main)
# 16
# 17                         UseGalaxy.eu, UseGalaxy.fr
# 18                                       UseGalaxy.be
# 19  GalaxyTrakr, UseGalaxy.eu, UseGalaxy.org (Main...
# 20                               UseGalaxy.org (Main)
# 21                                       UseGalaxy.eu
# 22                         UseGalaxy.be, UseGalaxy.eu
# 23
# 24  UseGalaxy.eu, UseGalaxy.no, UseGalaxy.org (Mai...
# 25                                       UseGalaxy.eu
# 26                                       UseGalaxy.eu
# 27  UseGalaxy.be, UseGalaxy.eu, UseGalaxy.no, UseG...
# 28                               UseGalaxy.org (Main)
# 29                         UseGalaxy.eu, UseGalaxy.fr
# 30
# 31
# 32                                       UseGalaxy.eu
# 33                                       UseGalaxy.eu
# 34                                       UseGalaxy.eu
# 35                         UseGalaxy.be, UseGalaxy.eu
# 36  UseGalaxy.eu, UseGalaxy.no, UseGalaxy.org (Mai...
# 37                                       UseGalaxy.eu
# 38  UseGalaxy.be, UseGalaxy.eu, UseGalaxy.fr, UseG...
# 39   UseGalaxy.be, UseGalaxy.eu, UseGalaxy.org (Main)
# 40
#
#              Servers with tool but different versions
# 0
# 1
# 2   GalaxyTrakr, HyPhy HIV NGS Tools, MISSISSIPPI,...
# 3                                        UseGalaxy.eu
# 4   Galaxy@AuBi, GalaxyTrakr, UseGalaxy.be, UseGal...
# 5              Galaxy@AuBi, GalaxyTrakr, UseGalaxy.fr
# 6                  UseGalaxy.fr, UseGalaxy.org (Main)
# 7                  UseGalaxy.no, UseGalaxy.org (Main)
# 8   Galaxy@AuBi, GalaxyTrakr, MISSISSIPPI, UseGala...
# 9                          UseGalaxy.eu, UseGalaxy.no
# 10
# 11
# 12  Galaxy@AuBi, GalaxyTrakr, MISSISSIPPI, UseGala...
# 13
# 14
# 15  GalaxyTrakr, UseGalaxy.fr, UseGalaxy.no, UseGa...
# 16                         UseGalaxy.eu, UseGalaxy.no
# 17
# 18       UseGalaxy.fr, UseGalaxy.no, UseGalaxy.org.au
# 19
# 20                     UseGalaxy.no, UseGalaxy.org.au
# 21
# 22  UseGalaxy.fr, UseGalaxy.no, UseGalaxy.org (Mai...
# 23                                       UseGalaxy.eu
# 24                         UseGalaxy.be, UseGalaxy.fr
# 25  UseGalaxy.be, UseGalaxy.no, UseGalaxy.org (Mai...
# 26
# 27                                        GalaxyTrakr
# 28                     UseGalaxy.no, UseGalaxy.org.au
# 29
# 30  UseGalaxy.eu, UseGalaxy.org, UseGalaxy.org.au,...
# 31
# 32                 UseGalaxy.fr, UseGalaxy.org (Main)
# 33                 UseGalaxy.no, UseGalaxy.org (Main)
# 34       UseGalaxy.be, UseGalaxy.no, UseGalaxy.org.au
# 35                     UseGalaxy.no, UseGalaxy.org.au
# 36                                       UseGalaxy.be
# 37       UseGalaxy.be, UseGalaxy.no, UseGalaxy.org.au
# 38                     UseGalaxy.no, UseGalaxy.org.au
# 39  GalaxyTrakr, UseGalaxy.fr, UseGalaxy.no, UseGa...
# 40

# %% [markdown]
# ## Important Links and APIs

# %%
training_url = 'https://training.galaxyproject.org/training-material/tags/microgalaxy/embed.html'
training_material_api = ''
youtube_api_key = '' #'YOUR_YOUTUBE_API_KEY'
plausible_api_key = ""  #'YOUR_PLAUSIBLE_API_KEY'

# %% [markdown]
# ## microGalaxy GTN Youtube Videos Stats Extraction

# %% [markdown]
# ### Functions extracting microGalaxy training material names, information and plausible links

# %%
# Function to fetch and parse the HTML content
def fetch_and_parse_html(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup

# Function to extract table data and create a DataFrame
def extract_table_data(soup):
    tables = soup.find_all('table')
    
    all_rows = []
    for table in tables:
        headers = [header.text.strip() for header in table.find_all('th')]
        rows = []
        for row in table.find_all('tr')[1:]:
            row_data = [data.text.strip() for data in row.find_all('td')]
            rows.append(row_data)
        all_rows.extend(rows)
    
    df = pd.DataFrame(all_rows, columns=headers)
    return df

# Function to remove 'Hands-on: Hands-on: ' from Lesson column entries
def clean_lesson_column(df):
    df['Lesson'] = df['Lesson'].str.replace('Hands-on: Hands-on: ', '', regex=False)
    df['Lesson'] = df['Lesson'].str.split('\n').str[0]
    return df

# Function to create a boolean column indicating if 'Recordings' is present
def create_recordings_present_column(df):
    df['Recordings_Present'] = df['Recordings'].str.startswith('video\n')
    return df

# %% [markdown]
# ### Functions to extract youtube stats, checking the GalaxyProject channel, for every microGalaxy training and return the video date and number of views

# %%
# Function to get video details for each lesson with channel, title, and order check
def get_video_details(api_key, video_titles, channel_id='UCx3M4_d3M__lXf9OX8I5Kdg', cache_file='video_cache.json'):
    try:
        with open(cache_file, 'r') as file:
            cache = json.load(file)
    except FileNotFoundError:
        cache = {}

    youtube = build('youtube', 'v3', developerKey=api_key)
    video_details = {}

    for title in video_titles:
        if title in cache:
            video_details[title] = cache[title]
        else:
            # Print the query
            query = f'{title} GalaxyProject site:youtube.com'
            print(f'Query: {query}')

            # Execute the YouTube API request
            request = youtube.search().list(
                part='id,snippet',
                q=query,
                type='video',
                maxResults=1
            )
            response = request.execute()

            items = response.get('items', [])
            if items:
                snippet = items[0]['snippet']
                video_id = items[0]['id']['videoId']
                video_url = f'https://www.youtube.com/watch?v={video_id}'
               

                # Check if the video is from the specified channel and has a title exactly matching the Lesson entry
                if snippet['channelId'] == channel_id and title.lower() in snippet['title'].lower():
                    video_details[title] = {
                        'Video_Count': int(snippet.get('statistics', {}).get('viewCount', 0)),
                        'Published_Date': snippet.get('publishedAt', ''),
                        'Video_ID': video_id,
                        'Video_URL': video_url
                    }
                else:
                    # Video doesn't meet the criteria, set Video_Count to None
                    video_details[title] = {
                        'Video_Count': None,
                        'Published_Date': '',
                        'Video_ID': None,
                        'Video_URL': None
                    }

                # Update cache
                cache[title] = video_details[title]

    # Save updated cache to file
    with open(cache_file, 'w') as file:
        json.dump(cache, file)

    return video_details

# Adding youtube videos statistics
def creating_trainings_videos_stats():

    # Fetch and parse HTML
    soup = fetch_and_parse_html(training_url)
    
    # Extract table data and create a DataFrame
    df = extract_table_data(soup)
    
    # Clean the 'Lesson' column
    df_cleaned_lesson = clean_lesson_column(df)
    
    # Create a boolean column indicating if 'Recordings' is present
    df_final = create_recordings_present_column(df_cleaned_lesson)
    
    # Get video details for each lesson with channel, title, and order check
    video_titles = df_final['Lesson'].tolist()
    video_details = get_video_details(youtube_api_key, video_titles)
    
    # Create new columns 'Video_Count', 'Published_Date', 'Video_ID', and 'Video_URL'
    df_final['Video_Count'] = df_final['Lesson'].apply(lambda title: video_details.get(title, {}).get('Video_Count'))
    df_final['Published_Date'] = df_final['Lesson'].apply(lambda title: video_details.get(title, {}).get('Published_Date'))
    df_final['Video_ID'] = df_final['Lesson'].apply(lambda title: video_details.get(title, {}).get('Video_ID'))
    df_final['Video_URL'] = df_final['Lesson'].apply(lambda title: video_details.get(title, {}).get('Video_URL'))
    
    # Drop duplicates based on the 'Lesson' column
    df_final = df_final.drop_duplicates(subset=['Lesson'])

    # Keep only the desired columns
    df_final = df_final[['Lesson', 'Recordings_Present', 'Video_Count', 'Published_Date', 'Video_ID', 'Video_URL']]
   
    # Display the final DataFrame
    display(df_final)

# Creating training videos statisitics table
creating_trainings_videos_stats()
# Out:
# Query: QIIME 2 Cancer Microbiome Intervention external-link GalaxyProject site:youtube.com
#                                                Lesson  Recordings_Present  \
# 0             Assembly of metagenomic sequencing data               False
# 1   Genome Assembly of a bacterial genome (MRSA) s...               False
# 2            Making sense of a newly assembled genome               False
# 3                                  Unicycler Assembly               False
# 4   Identifying tuberculosis transmission links: f...               False
# 5   Tree thinking for tuberculosis evolution and e...               False
# 6                         Bacterial Genome Annotation               False
# 7                       Genome annotation with Prokka                True
# 8   Refining Genome Annotations with Apollo (proka...                True
# 9    Comparative gene analysis in unannotated genomes               False
# 10      16S Microbial Analysis with mothur (extended)               False
# 11         16S Microbial Analysis with mothur (short)               False
# 12          16S Microbial analysis with Nanopore data               False
# 13  Analyses of metagenomics data - The global pic...               False
# 14                    Antibiotic resistance detection               False
# 16             Binning of metagenomic sequencing data               False
# 17  Identification of the micro-organisms in a bee...               False
# 18  Metatranscriptomics analysis using microbiome ...               False
# 19  Metatranscriptomics analysis using microbiome ...               False
# 20  Pathogen detection from (direct Nanopore) sequ...               False
# 21  QIIME 2 Cancer Microbiome Intervention externa...               False
# 22  Taxonomic Profiling and Visualization of Metag...               False
# 23                            Metaproteomics tutorial                True
# 24                      metaQuantome 1: Data creation               False
# 25                           metaQuantome 2: Function               False
# 26                           metaQuantome 3: Taxonomy               False
# 27            Calling variants in non-diploid systems               False
# 28                   M. tuberculosis Variant Analysis                True
# 29                          Microbial Variant Calling               False
#
#    Video_Count Published_Date Video_ID Video_URL
# 0         None                    None      None
# 1         None                    None      None
# 2         None                    None      None
# 3         None                    None      None
# 4         None                    None      None
# 5         None                    None      None
# 6         None                    None      None
# 7         None                    None      None
# 8         None                    None      None
# 9         None                    None      None
# 10        None                    None      None
# 11        None                    None      None
# 12        None                    None      None
# 13        None                    None      None
# 14        None                    None      None
# 16        None                    None      None
# 17        None                    None      None
# 18        None                    None      None
# 19        None                    None      None
# 20        None                    None      None
# 21        None           None     None      None
# 22        None                    None      None
# 23        None                    None      None
# 24        None                    None      None
# 25        None                    None      None
# 26        None                    None      None
# 27        None                    None      None
# 28        None                    None      None
# 29        None                    None      None

# %% [markdown]
# ## microGalaxy GTN visitors and feedback (Plausible)

# %%
# Get the current date
current_date = datetime.now().strftime('%Y-%m-%d')

# Send a GET request to the URL
response = requests.get(training_url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Extract lesson links
lesson_links = [a['href'] for a in soup.find_all('a', href=True)]

# Base URL for plausible
plausible_base_url = "https://plausible.galaxyproject.eu"

# Filter only the lesson links that end with "tutorial.html"
lesson_links = [link for link in lesson_links if link.endswith("tutorial.html")]

# Dictionary to store plausible download links for each lesson
plausible_download_links = {}

# Rest of the code remains unchanged...

# Generate plausible download links for the filtered lesson links using the current date
for link in lesson_links:
    plausible_download_link = f"{plausible_base_url}/training.galaxyproject.org/export?period=all&date={current_date}&filters=%7B%22page%22%3A%22{quote(link)}%22%7D&with_imported=true&interval=month"
    plausible_download_links[link] = plausible_download_link


# Directory to store downloaded zip files
download_directory = "plausible_zips"

# Create the directory if it doesn't exist
os.makedirs(download_directory, exist_ok=True)

# Iterate through each lesson and download the plausible zip file
for lesson, download_link in plausible_download_links.items():
    # Properly encode the URL
    encoded_link = quote(download_link, safe=':/?&=')

    # Specify cache control headers to avoid caching
    headers = {
        "Authorization": f"Bearer {plausible_api_key}",
        "Cache-Control": "no-cache, no-store, must-revalidate",
        "Pragma": "no-cache",
        "Expires": "0"
    }

    # Make the request with the encoded URL and cache control headers
    response = requests.get(encoded_link, headers=headers)
    
    if response.status_code == 200:
        # Generate a unique name for the zip file
        zip_filename = f"{lesson.replace('/', '_')}_{current_date}_plausible.zip"
        zip_filepath = os.path.join(download_directory, zip_filename)
        
        # Save the zip file with the unique filename
        with open(zip_filepath, 'wb') as zip_file:
            zip_file.write(response.content)
        
        # Extract visitors.csv from the zip file
        with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
            # Get the name of the visitors.csv file in the zip
            csv_name = [name for name in zip_ref.namelist() if name.lower().endswith('visitors.csv')][0]
            
            # Generate a new name for the visitors.csv file
            new_csv_name = f"{lesson.replace('/', '_')}_{current_date}_visitors.csv"
            
            # Extract the visitors.csv file with the new name
            zip_ref.extract(csv_name, download_directory)
            
            # Rename the visitors.csv file
            os.rename(os.path.join(download_directory, csv_name), os.path.join(download_directory, new_csv_name))
            
            # Read visitors.csv into a DataFrame
            visitors_df = pd.read_csv(os.path.join(download_directory, new_csv_name))
        
        # Print the number of visitors for the lesson
        print(f"For {lesson}, Number of Visitors: {visitors_df['visitors'].sum()}")
    else:
        print(f"Error fetching Plausible metrics for {lesson}: {response.status_code}")
# Out:
# For /training-material/topics/assembly/tutorials/metagenomics-assembly/tutorial.html, Number of Visitors: 1795696
# For /training-material/topics/assembly/tutorials/mrsa-illumina/tutorial.html, Number of Visitors: 1795696
# For /training-material/topics/assembly/tutorials/ecoli_comparison/tutorial.html, Number of Visitors: 1795696
# For /training-material/topics/assembly/tutorials/unicycler-assembly/tutorial.html, Number of Visitors: 1795696
# For /training-material/topics/evolution/tutorials/mtb_transmission/tutorial.html, Number of Visitors: 1795696
# For /training-material/topics/evolution/tutorials/mtb_phylogeny/tutorial.html, Number of Visitors: 1795697
# For /training-material/topics/genome-annotation/tutorials/bacterial-genome-annotation/tutorial.html, Number of Visitors: 1795697
# For /training-material/topics/genome-annotation/tutorials/annotation-with-prokka/tutorial.html, Number of Visitors: 1795697
# For /training-material/topics/genome-annotation/tutorials/apollo/tutorial.html, Number of Visitors: 1795697
# For /training-material/topics/genome-annotation/tutorials/gene-centric/tutorial.html, Number of Visitors: 1795697
# For /training-material/topics/microbiome/tutorials/mothur-miseq-sop/tutorial.html, Number of Visitors: 1795697
# For /training-material/topics/microbiome/tutorials/mothur-miseq-sop-short/tutorial.html, Number of Visitors: 1795698
# For /training-material/topics/microbiome/tutorials/nanopore-16S-metagenomics/tutorial.html, Number of Visitors: 1795698
# For /training-material/topics/microbiome/tutorials/general-tutorial/tutorial.html, Number of Visitors: 1795698
# For /training-material/topics/microbiome/tutorials/plasmid-metagenomics-nanopore/tutorial.html, Number of Visitors: 1795698
# For /training-material/topics/microbiome/tutorials/metagenomics-assembly/tutorial.html, Number of Visitors: 1795698
# For /training-material/topics/microbiome/tutorials/metagenomics-binning/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/microbiome/tutorials/beer-data-analysis/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/microbiome/tutorials/metatranscriptomics/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/microbiome/tutorials/metatranscriptomics-short/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/microbiome/tutorials/pathogen-detection-from-nanopore-foodborne-data/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/microbiome/tutorials/taxonomic-profiling/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/proteomics/tutorials/metaproteomics/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/proteomics/tutorials/metaquantome-data-creation/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/proteomics/tutorials/metaquantome-function/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/proteomics/tutorials/metaquantome-taxonomy/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/variant-analysis/tutorials/non-dip/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/variant-analysis/tutorials/tb-variant-analysis/tutorial.html, Number of Visitors: 1795699
# For /training-material/topics/variant-analysis/tutorials/microbial-variants/tutorial.html, Number of Visitors: 1795699

# %% [markdown]
# ### Generating Plausible links for every training on GTN with microGalaxy tag

# %%
# URL of the training page
training_url = "https://training.galaxyproject.org/training-material/tags/microgalaxy/embed.html"

# Send a GET request to the URL
response = requests.get(training_url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Extract lesson links
lesson_links = [a['href'] for a in soup.find_all('a', href=True)]

# Base URL for plausible
plausible_base_url = "https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page="

# Filter only the lesson links that end with "tutorial.html"
lesson_links = [link for link in lesson_links if link.endswith("tutorial.html")]

# Use a set to store unique plausible links
unique_plausible_links = set()

# Generate plausible links for the filtered lesson links and add to the set
for link in lesson_links:
    plausible_link = plausible_base_url + quote(link)
    unique_plausible_links.add(plausible_link)

# Print the unique plausible links
for link in unique_plausible_links:
    print(link)
# Out:
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/genome-annotation/tutorials/apollo/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/mothur-miseq-sop/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/general-tutorial/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/genome-annotation/tutorials/bacterial-genome-annotation/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/assembly/tutorials/mrsa-illumina/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/proteomics/tutorials/metaquantome-taxonomy/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/pathogen-detection-from-nanopore-foodborne-data/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/evolution/tutorials/mtb_transmission/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/assembly/tutorials/ecoli_comparison/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/variant-analysis/tutorials/non-dip/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/genome-annotation/tutorials/annotation-with-prokka/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/nanopore-16S-metagenomics/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/assembly/tutorials/metagenomics-assembly/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/proteomics/tutorials/metaquantome-function/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/evolution/tutorials/mtb_phylogeny/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/taxonomic-profiling/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/variant-analysis/tutorials/tb-variant-analysis/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/plasmid-metagenomics-nanopore/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/beer-data-analysis/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/proteomics/tutorials/metaproteomics/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/assembly/tutorials/unicycler-assembly/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/proteomics/tutorials/metaquantome-data-creation/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/metatranscriptomics/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/genome-annotation/tutorials/gene-centric/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/mothur-miseq-sop-short/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/metatranscriptomics-short/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/metagenomics-binning/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/variant-analysis/tutorials/microbial-variants/tutorial.html
# https://plausible.galaxyproject.eu/training.galaxyproject.org?period=all&page=/training-material/topics/microbiome/tutorials/metagenomics-assembly/tutorial.html
